# %%
# Variables. 

# Let's declare variables of various data types.

# %%
# Mutable VS Immutable. 

# We will work with the data structers we created above. 
# List is a mutable variable. We can update it at any time, we can add new values or delete old ones. 
# Another examples of mutable variables are dictionaries and sets. 


# Whereas tuple - is immutable, meaning that we cannot modify it after it was created. It will remain fixed. 
# We can update it in this way:

# Important - this way will keep adding new tuples everytime the line is executed. Not as flexible and should be used in special cases only.

# %%
# Global VS Local. 

# random_number is a local variable in this case. If we try to access this variable outside of my_function(), it will give us a NameError.


# Let's work with one of the variables we created before. 

# Variable name is not exclusive to any function, so we can use it at any point throughout the program.

# %%
# Some arithmetics and strings operations. 
# Let's say we want to format the output nicely. We will practice doing so on the example  of printing out patient's hemoglobin 
# level with the reference 12.0-15.5 using f-string.


# f-string

# f-string are more flexible since concatenation only works with str data type. 

# Convert glucose from mg/dL to mmol/L (approx factor: 1 mg/dL = 0.0555 mmol/L).
glucose_mg_dl = 95
glucose_mmol_l = glucose_mg_dl * 0.0555
print(f"Glucose: {glucose_mg_dl} mg/dL = {glucose_mmol_l:.1f} mmol/L")
# Out:
# Patient's hemoglobin is 10.8 g/dL. (Reference 12.0-15.5).
# Glucose: 95 mg/dL = 5.3 mmol/L

# %% [markdown]
# ## Practice

# %%
# TODO: create the variables with the following names: patient_name, height_cm, weight_kg, systolic_bp, diastolic_bp
#       choose reasonable values and print the type of these variables using type() command. 






# TODO: print a sentence using an f-string
# Example output:
# "Grace is 165 cm tall and weights 55 kg with BP 120/80 mmHg."

# %%
# TODO: A CBC reports WBC = 6.2; store 6.2 in a variable wbc_k_per_ul and compute the number of cells per uL (wbc_per_ul; multiply by 1000). 
#       Print the computer value as an integer. (Hint: use int() in your print statement)

# %%
from math import log2

# TODO: Log2 Fold Change (Gene Expression) quantifies the difference in expression between two conditions (treated vs untreated)
#       by taking the base-2 logarithm of their ratio. You will need to calculate fold change (FC) and log2 FC. 
#       Use the following formulas: fold change (fc) = treated / control and log2fc = log2(fc)
#       Create two variables for your computation, treated and control. Store 20.0 and 5.0 in the variables, respectively. 
#       Print the computed values using f-string. Round up to 2 decimal points (see glucose example for reference)
